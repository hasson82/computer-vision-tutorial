# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# open image
img = cv2.imread('..\\..\\data\\jj_and_omer.jpeg')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fixed_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %%
img = cv2.imread('..\\..\\data\\jj_and_omer.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
type(img)
cv2.circle(img, center=(200, 150), radius=145, color=(0, 255, 0), thickness=10)
gray = cv2.GaussianBlur(img, (15, 15), 0)

plt.imshow(gray)

# %%
type(gray)
gray.ndim
circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, 1, 200, param1=100, param2=50, minRadius=10, maxRadius=140)
circles = np.uint16(np.around(circles))
circles
# Out:
# array([[[200, 150, 139]]], dtype=uint16)

# %%
# Create a blank white image
output = np.ones_like(img) * 255

# Draw the circles on the white image
for i in circles[0,:]:
    cv2.circle(output, (i[0], i[1]), i[2], (0, 0, 0), -1)

# Save the result
cv2.imwrite('output.jpg', output)

plt.imshow(output, cmap='gray')

# %%
cv2.rectangle(fixed_img, pt1=(270, 410), pt2=(405, 540), color=(255, 0, 0), thickness=10)
cv2.circle(fixed_img, center=(200, 150), radius=145, color=(0, 255, 0), thickness=10)
# Out:
# array([[[103, 204, 111],
#         [103, 203, 109],
#         [103, 203, 109],
#         ...,
#         [102, 202, 102],
#         [101, 201, 105],
#         [101, 201, 105]],
#
#        [[103, 204, 111],
#         [103, 203, 109],
#         [103, 203, 109],
#         ...,
#         [102, 202, 102],
#         [101, 201, 105],
#         [101, 201, 105]],
#
#        [[103, 204, 111],
#         [103, 203, 109],
#         [103, 203, 109],
#         ...,
#         [102, 202, 102],
#         [101, 201, 105],
#         [101, 201, 105]],
#
#        ...,
#
#        [[103,  51,  70],
#         [103,  48,  74],
#         [103,  61,  61],
#         ...,
#         [138, 160,  59],
#         [138, 159,  58],
#         [138, 159,  58]],
#
#        [[103,  47,  76],
#         [103,  43,  83],
#         [105,  55,  74],
#         ...,
#         [138, 162,  60],
#         [138, 161,  60],
#         [138, 161,  60]],
#
#        [[103,  42,  85],
#         [103,  42,  85],
#         [105,  54,  76],
#         ...,
#         [138, 161,  60],
#         [138, 161,  60],
#         [138, 162,  60]]], dtype=uint8)

# %%
plt.imshow(fixed_img)

# %%
#flip image
flip_img = cv2.flip(fixed_img, 1)
flipX2_img = cv2.flip(flip_img, 0)
plt.imshow(flipX2_img)
