# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('..\\data\\jj_and_omer.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=492x831>

# %%
img_arr = np.array(img)
img_arr[:,:,1] = 0
img_arr[:,:,2] = 0
plt.imshow(img_arr)
